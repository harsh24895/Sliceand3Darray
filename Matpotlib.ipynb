# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
x = list(range(0,10))
y = list(range(-10,0))     

plt.plot(x,y)

# %%
a = [0,-100,25,67,-32]
b = [0,3,5,8,9]
plt.plot(a,b)
